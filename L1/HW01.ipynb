# %% [markdown]
# # HW01: Các câu lệnh Linux, Python
#
# (Cập nhật lần cuối 06/11/2025)
#
# Họ tên: Trần Hoài Thiện Nhân
#
# MSSV: 23127238

# %% [markdown]
# ---

# %% [markdown]
# ## Cách làm bài và nộp bài

# %% [markdown]
# &#9889; Bạn lưu ý là mình sẽ dùng chương trình hỗ trợ chấm bài nên bạn cần phải tuân thủ chính xác qui định mà mình đặt ra, nếu không rõ thì hỏi, chứ không nên tự tiện làm theo ý của cá nhân.
#
# **Cách làm bài**
#
# Bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV vào phần đầu file ở bên trên. Trong file, bạn làm bài ở những chỗ có ghi là:
# ```python
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
# hoặc đối với những phần code không bắt buộc thì là:
# ```python
# # YOUR CODE HERE (OPTION)
# ```
# hoặc đối với markdown cell thì là:
# ```markdown
# YOUR ANSWER HERE
# ```
# Tất nhiên, khi làm thì bạn xóa dòng `raise NotImplementedError()` đi.
# Đối những phần yêu cầu code thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa; nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test. Trong một số trường hợp, các bộ test có thể sẽ không đầy đủ; nghĩa là, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng hoàn toàn.
#
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Nhưng khi nộp bài thì bạn xóa các cell mà bạn tự tạo, xóa hoặc comment các câu lệnh in ra màn hình. Bạn lưu ý <font color=red>không được tự tiện xóa các cell hay sửa code của Thầy</font> (trừ những chỗ được phép sửa như đã nói ở trên).
#
# Bạn cố gắng giữ cho code rõ ràng, ngăn nắp: đặt tên biến gợi ý, comment ở những chỗ cần comment, giữ cho một dòng code không quá dài (vì nếu không thì người đọc sẽ phải mất công scroll, bạn có thể dùng qui tắc: một dòng code chỉ nên có tối đa là 79 ký tự).
#
# Trong khi làm bài, thường xuyên `Ctrl + S` để lưu lại bài làm của bạn, tránh mất mát thông tin.
#
#
# *Nên nhớ mục tiêu chính ở đây là <font color=green>học, học một cách chân thật</font>. Bạn có thể thảo luận ý tưởng với bạn khác, nhưng <font color=green>code và bài làm phải là của bạn, dựa trên sự hiểu thật sự của bạn</font>. <font color=red>Nếu vi phạm thì sẽ bị 0 điểm cho toàn bộ môn học.</font>*
#
# **Cách nộp bài**
#
# Khi chấm bài, đầu tiên mình sẽ chọn `Kernel` - `Restart & Run All` để restart và chạy tất cả các cell trong notebook của bạn; do đó, trước khi nộp bài, bạn nên chạy thử `Kernel` - `Restart & Run All` để đảm bảo mọi chuyện diễn ra đúng như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo cấu trúc sau:
# - Thư mục `MSSV` (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`)
#     - File `HW01.ipynb` (không cần nộp các file khác)
#
# Cuối cùng, bạn nén thư mục `MSSV` này lại và nộp ở link trên moodle. <font color=red>Bạn lưu ý tuân thủ chính xác qui định nộp bài.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Môi trường code

# %% [markdown]
# Ta thống nhất trong môn này:
# - Code trên môi trường Linux (bạn đã setup ở HW0)
# - Dùng Jupyter Notebook hoặc Jupyter Lab để code file .ipynb. Lưu ý: bạn <font color=red>không dùng Google Colab</font>, vì Google Colab có thể xóa một số thông tin meta mà chương trình hỗ trợ chấm bài của mình đã tạo trong file bài tập
# - Dùng phiên bản các package như trong file "min_ds-env.yml" (bạn xem trong HW0 cách dùng Conda để tạo môi trường code từ file .yml và cách kích hoạt môi trường này sau khi đã tạo)

# %%
import sys
sys.executable
# Out:
# '/home/thtn/anaconda3/envs/min_ds-env/bin/python'

# %% [markdown]
# Nếu không có vấn đề gì thì file chạy python sẽ là file của môi trường code "min_ds-env".
#
# Trong bài này, ngoài Git & Jupyter Notebook/Lab thì bạn chỉ dùng Python, không dùng các thư viện khác như Numpy, Pandas, ... Trong Python, khi đọc/ghi file csv thì bạn cũng không được dùng các thư viện hỗ trợ như thư viện `csv`.

# %% [markdown]
# ---

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import datetime
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ---

# %% [markdown]
# ## Thu thập dữ liệu (3.5đ)

# %% [markdown]
# Trong bài tập này, bạn sẽ lấy dữ liệu log của [thùng chứa nbdime](https://github.com/namlnhut/nbdime). Nbdime là công cụ giúp Git có thể diff và merge file Notebook một cách phù hợp (thay vì chỉ coi như là một file text thông thường). Link mình cung cấp không phải là link đến thùng chứa gốc của nbdime mà là thùng chứa mình "fork" (đại khái là tạo ra một bản copy) từ thùng chứa gốc. Lý do: mình muốn cố định lại dữ liệu log để có thể cung cấp các bộ test để bạn phần nào biết là đã code đúng hay chưa (còn nếu dùng thùng chứa gốc thì dữ liệu log có thể sẽ thay đổi trong vài ngày tới, các bộ test lúc đó có thể sẽ không còn đúng nữa).
#
# Để có thể lấy dữ liệu log thì việc đầu tiên bạn cần làm ở cell bên dưới là:
#
# - Dùng câu lệnh Git để clone thùng chứa về; bạn clone vào một thư mục cùng cấp với file notebook này. <font color=gray>Gợi ý: trong Jupyter Notebook, ở code cell, bạn có thể thực hiện một câu lệnh Linux (bao gồm câu lệnh Git) bằng cách thêm dấu ! ở đầu.</font>
# - Sau đó, để xem thử thư mục vừa clone có nặng không, bạn tính dung lượng tổng cộng của thư mục này và lưu vào biến `repo_size` (`repo_size` là một con số, đơn vị là MB); ta thống nhất: (i) dùng cờ `--apparent-size` khi dùng câu lệnh `du`, (ii) code chỉ cần chạy đúng với thùng chứa cụ thể này. <font color=gray>Gợi ý: trong Jupyter Notebook, bạn có thể gán kết quả của câu lệnh Linux vào biến Python.</font> \
# @ Các bạn dùng Mac: trong Mac thì mình nghe nói là câu lệnh `du` không có cờ `--apparent-size` (do câu lệnh `du` của Mac là bản BSD, còn của Linux là bản GNU); bạn có thể xem thử cách cài câu lệnh `du` bản GNU ở [video này](https://youtu.be/VGgTmxXp7xQ?t=894) (trong video là nói về câu lệnh `grep` nhưng mình nghĩ cũng sẽ tương tự với câu lệnh `du`).

# %%
# YOUR CODE HERE
# !git clone https://github.com/namlnhut/nbdime.git
size_str = !du --apparent-size -s nbdime | cut -f1
repo_size = float(size_str[0]) / 1024

# result = !du -sh --apparent-size nbdime
# size_str = result[0].split()[0]
# repo_size = float(size_str.replace('M', ''))

print(f"\nRepository size: {repo_size} MB")
# Out:
# Cloning into 'nbdime'...
# remote: Enumerating objects: 14752, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 14752 (delta 9), reused 11 (delta 5), pack-reused 14720 (from 1)
# Receiving objects: 100% (14752/14752), 14.47 MiB | 2.52 MiB/s, done.
# Resolving deltas: 100% (10602/10602), done.
#
# Repository size: 20.96875 MB

# %% [markdown]
# Sau khi đã clone thùng chứa về, việc kế tiếp của bạn là dùng các câu lệnh Linux (trong đó có các câu lệnh Git) và Python để lấy dữ liệu log rồi lưu xuống file "log.tsv" (định dạng tsv tương tự như csv nhưng các giá trị được cách nhau bởi tab). Để dễ hình dung, bạn có thể dùng Jupyter Lab để mở xem file kết quả đúng "correct_log.tsv" mà mình cung cấp. Như bạn có thể thấy, mỗi dòng ứng với một commit (không tính dòng đầu - dòng chứa các tên cột) và gồm các thông tin:
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit, ngày được format theo chuẩn RFC2822 (xem phần gợi ý ở bên dưới để biết cách lấy ngày theo format này)
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy
#
# Tại sao mình dùng định dạng tsv thay vì csv? Vì dấu phẩy nhiều khả năng là sẽ có trong phần "subject" của message. Tab ít khả năng sẽ có hơn, nhưng nếu có thì bạn hãy thay bằng bốn khoảng trắng.
#
# <font color=gray>Gợi ý cho phần này:</font>
# - <font color=gray>Bạn có thể xem thêm về câu lệnh `git log` [ở đây](https://git-scm.com/book/en/v2/Git-Basics-Viewing-the-Commit-History)</font>
# - <font color=gray>Khi ở Notebook, bạn thử `cd` đến thư mục clone rồi `pwd` xem? Kết quả như vậy là vì khi thực hiện một dòng lệnh Linux ở Notebook thì Notebook sẽ tạo ra một terminal tạm thời để thực thi dòng lệnh đó trong phút chốc. Như vậy, câu lệnh `cd` vẫn là có `cd` đến thư mục clone nhưng là ở terminal tạm thời; khi câu lệnh `cd` chạy xong thì terminal tạm thời này sẽ được đóng và ta vẫn ở thư mục mà hiện chứa file Notebook. Để có thể `cd` rồi `pwd` thì một cách là ghi 2 câu lệnh này trên một dòng và cách nhau bởi `&&`; lúc này thì cả 2 câu lệnh sẽ được thực thi trên cùng một terminal</font>

# %%
# YOUR CODE HERE
log_output = !cd nbdime && git log --name-only --date=rfc --pretty=format:"%h%x09%p%x09%an%x09%ae%x09%ad%x09%s"

lines = []
current_commit = None

for line in log_output:
    line = line.strip()
    if not line:
        continue
    
    if '\t' in line:
        parts = line.split('\t')
        if len(parts) == 6:
            current_commit = {
                'Id': parts[0],
                'ParentIds': parts[1],
                'AuthorName': parts[2],
                'AuthorEmail': parts[3],
                'AuthorDate': parts[4],
                'Subject': parts[5].replace('\t', '    '),
                'ChangedFiles': []
            }
            lines.append(current_commit)
    else:
        # It's a changed file
        if current_commit is not None:
            current_commit['ChangedFiles'].append(line)

with open('log.tsv', 'w') as f:
    f.write('Id\tParentIds\tAuthorName\tAuthorEmail\tAuthorDate\tSubject\tChangedFiles\n')
    for commit in lines:
        changed_files = ','.join(commit['ChangedFiles']) if commit['ChangedFiles'] else ''
        f.write(f"{commit['Id']}\t{commit['ParentIds']}\t{commit['AuthorName']}\t"
                f"{commit['AuthorEmail']}\t{commit['AuthorDate']}\t{commit['Subject']}\t"
                f"{changed_files}\n")

# %%
# TEST
file = open('log.tsv', 'r')
log = file.read()
file.close()
file = open('correct_log.tsv', 'r')
correct_log = file.read()
file.close()
assert log == correct_log

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột? (0.5đ)

# %% [markdown]
# Đầu tiên, bạn sẽ đọc dữ liệu từ file "log.tsv" (nếu phần thu thập dữ liệu bạn làm chưa đúng thì bạn có thể đọc từ file "correct_log.tsv" mà mình đã cung cấp). Bạn lưu kết quả đọc được vào biến `cols`. Biến `cols` là một dictionary, trong đó mỗi phần tử ứng với một cột, key là chuỗi ứng với tên cột, value là list chứa các giá trị của cột (mỗi giá trị bạn cứ tạm để kiểu dữ liệu là chuỗi).
#
# Kế tiếp, từ biến `cols`, bạn sẽ tính số dòng và số cột, rồi lần lượt lưu vào hai biến là `num_rows` và `num_cols`.

# %%
# YOUR CODE HERE
def read_log_tsv(filepath):
    cols = {
        'Id': [], 
        'ParentIds': [], 
        'AuthorName': [], 
        'AuthorEmail': [],
        'AuthorDate': [], 
        'Subject': [], 
        'ChangedFiles': []
    }
    
    with open(filepath, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        
    header = lines[0].strip().split('\t')
    for line in lines[1:]:
        values = line.strip().split('\t')
        if len(values) < 6:
            continue
        cols['Id'].append(values[0])
        cols['ParentIds'].append(values[1])
        cols['AuthorName'].append(values[2])
        cols['AuthorEmail'].append(values[3])
        cols['AuthorDate'].append(values[4])
        cols['Subject'].append(values[5])
        cols['ChangedFiles'].append(values[6] if len(values) > 6 else '')
    return cols

cols = read_log_tsv('log.tsv')
#cols = read_log_tsv('correct_log.tsv')

num_rows = len(cols['Id'])
num_cols = len(cols)

num_rows
# Out:
# 2149

# %%
# TEST
assert num_rows == 2149
assert num_cols == 7
assert set(cols.keys()) == set(['Id', 'ParentIds', 'AuthorName', 
                                'AuthorEmail', 'AuthorDate', 'Subject', 
                                'ChangedFiles'])
id_col_len = len(cols['Id'])
for col_name in cols:
    assert len(cols[col_name]) == id_col_len

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng ứng với một commit. Có vẻ không có dòng nào "lạc loài" (nghĩa là không có vấn đề các dòng có ý nghĩa khác nhau).

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không? (0.25đ)

# %% [markdown]
# Có lẽ là không có. Để chắc ăn thì một cách là ta có thể check cột "Id"; nếu cột "Id" không có giá trị bị lặp thì có thể kết luận là không có dòng bị lặp. Bạn sẽ làm vụ này và lưu kết quả check vào biến `duplicated_id`; biến này bằng True nếu cột "Id" có giá trị lặp và bằng False nếu ngược lại.

# %%
# YOUR CODE HERE
id_set = set()
duplicated_id = False
for id_val in cols['Id']:
    if id_val in id_set:
        duplicated_id = True
        break
    id_set.add(id_val)

# %%
# TEST
assert duplicated_id == False

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì?

# %% [markdown]
# Vụ này mình đã nói lúc thu thập dữ liệu. Ở đây, mình ghi lại một lần nữa:
#
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không?

# %% [markdown]
# - Các cột "Id", "ParentIds", "AuthorName", "AuthorEmail", "Subject": kiểu dữ liệu dạng chuỗi là đúng rồi
# - Cột "ChangedFiles": hmm ... có lẽ tạm thời ta vẫn để dạng chuỗi, có gì cần thì ta sẽ xử lý sau
# - Cột "AuthorDate": cần chuyển từ kiểu dữ liệu dạng chuỗi sang datetime; để có thể tiếp tục khám phá tiếp thì ngay sau đây bạn sẽ tiền xử lý vụ này luôn

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Ở đây, bạn sẽ chuyển cột "AuthorDate" từ dạng chuỗi sang datetime. <font color=gray>Gợi ý: bạn xem [document](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes) để biết cách truyền format phù hợp cho hàm `strptime`.</font>

# %%
# YOUR CODE HERE
for i in range(len(cols['AuthorDate'])):
    cols['AuthorDate'][i] = datetime.datetime.strptime(
        cols['AuthorDate'][i], 
        '%a, %d %b %Y %H:%M:%S %z'
    )

print(f"First date: {cols['AuthorDate'][0]}")
# Out:
# First date: 2025-10-09 11:32:46+02:00

# %%
# TEST
assert type(cols['AuthorDate'][0]) == datetime.datetime
assert cols['AuthorDate'][0] == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu (tiếp tục)

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số (numeric) và dạng datetime, các giá trị được phân bố như thế nào? (0.5đ)

# %% [markdown]
# Ở đây thì không có cột dạng số, chỉ có một cột dạng datetime là cột "AuthorDate".
#
# Đầu tiên, bạn tính tỉ lệ % các giá trị thiếu của cột "AuthorDate". <font color=gray>Gợi ý: không cần code, có thể lập luận dựa vào kết quả khi chuyển cột "AuthorDate" từ dạng chuỗi sang datetime ở bên trên.</font>

# %% [markdown]
# YOUR ANSWER HERE
#
# When converting the "AuthorDate" column from string to datetime above, I did not handle the possibility that the value of the "AuthorDate" column was an empty string, and the code did not report an error when executing the `datetime.datetime.strptime` function (when the string is empty, it will be different from the format I defined $\to$ error $\to$ report an error). So all commits have an author date.

# %% [markdown]
# Tiếp theo, bạn tính min và max của cột "AuthorDate", rồi lần lượt lưu vào hai biến `author_date_min` và `author_date_max`.

# %%
# YOUR CODE HERE
author_date_min = min(cols['AuthorDate'])
author_date_max = max(cols['AuthorDate'])

# %%
# TEST
assert author_date_min == datetime.datetime(2015, 11, 9, 13, 13, 28, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))
assert author_date_max == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# Hmm ... Min và max của cột "AuthorDate" không có gì bất thường.

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng phân loại (categorical), các giá trị được phân bố như thế nào? (1.75đ)

# %% [markdown]
# Các cột dạng phân loại là các cột mà không phải là cột "AuthorDate". Bạn sẽ lưu thông tin của các cột này vào biến `cate_col_profiles`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một cột dạng phân loại, key là tên cột, value là list gồm: tỉ lệ % giá trị thiếu, số lượng các giá trị khác nhau (không tính giá trị thiếu), set chứa các giá trị khác nhau (không bao gồm giá trị thiếu).

# %%
# YOUR CODE HERE
def get_profiles(col_values):
    total = len(col_values)
    missing = sum(1 for v in col_values if v == '')
    unique_vals = set()
    for v in col_values:
        if v != '':
            unique_vals.add(v)
    missing_ratio = (missing / total) * 100
    return [missing_ratio, len(unique_vals), unique_vals]

cate_col_profiles = {}
categorical_cols = ['Id', 'ParentIds', 'AuthorName', 'AuthorEmail', 'Subject', 'ChangedFiles']
for col in categorical_cols:
    cate_col_profiles[col] = get_profiles(cols[col])

# %%
# TEST
assert set(cate_col_profiles.keys()) == {'AuthorEmail', 'AuthorName', 
                                         'ChangedFiles', 'Id', 
                                         'ParentIds', 'Subject'}
for col_name, col_profile in cate_col_profiles.items():
    assert len(col_profile) == 3
    assert len(col_profile[2]) == col_profile[1]
assert round(cate_col_profiles['ParentIds'][0], 3) == 0.047
assert round(cate_col_profiles['ChangedFiles'][0], 3) == 15.914
assert cate_col_profiles['ParentIds'][1] == 2029
assert cate_col_profiles['ChangedFiles'][1] == 934

# %%
# TEST (BY EYES)
print(f"{'ColName':12} {'Miss(%)':7} {'NumDifVals':10} {'SomeVals'}")
for col_name, col_profile in cate_col_profiles.items():
    print(f'{col_name:12} {col_profile[0]:<7.3f} {col_profile[1]:<10} {col_profile[2].__repr__()[:34]+"...":<}')
# Out:
# ColName      Miss(%) NumDifVals SomeVals
# Id           0.000   2149       {'a0726e5', '9560159', '5a6ba9b', ...
# ParentIds    0.047   2029       {'a0726e5', '20e07f4 58c5197', 'e4...
# AuthorName   0.000   55         {'Dean P', 'Cory Gwin', 'David Bau...
# AuthorEmail  0.000   58         {'stslve@amazon.com', 's.shanabroo...
# Subject      0.000   2058       {'Git diff api handles deleted/add...
# ChangedFiles 15.914  934        {'nbdime/merging/decisions.py,nbdi...

# %% [markdown]
# Bạn quan sát kết quả in ra ở trên (tạm thời chưa để ý đến cột "Miss(%)") và cho biết có gì bất thường không? Hay mọi thứ đều bình thường? Cho mình biết tại sao bạn lại kết luận như vậy.

# %% [markdown]
# YOUR ANSWER HERE
#
# Everything is normal:
# - `Id`           : 2149 unique $\to$ ok. It equals with the number of row above (each commit has unique ID)
# - `ParentIds`    : 2029 unique $\to$ ok. Some commits have same parent(s), normal in Git
# - `AuthorName`   : small number of unique values $\to$ ok. Few contributors and they can have the same name
# - `AuthorEmail`  : small number of unique values $\to$ ok. Few contributors
# - `Subject`      : many unique $\to$ ok. Each commit has different message and sometime, 2 contributions written the same subject for different subjects
# - `ChangedFiles` : 934 unique $\to$ ok. Many commits change same set of files or these are merge commits

# %% [markdown]
# Kế tiếp, bạn hãy cho in ra các dòng mà có giá trị thiếu (in sao là tùy bạn, miễn là dễ nhìn). Sau đó, bạn hãy quan sát các dòng này để xem tại sao lại bị thiếu (trong trường hợp, bạn không biết tại sao thì cứ ghi nhận là không biết tại sao).

# %%
# YOUR CODE HERE
print(f"{'Id':8} {'AuthorDate':20} {'ChangedFiles'}")
print("-" * 80)
for i in range(num_rows):
    if cols['ChangedFiles'][i] == '':
        date_str = cols['AuthorDate'][i].strftime("%Y-%m-%d %H:%M")
        print(f"{cols['Id'][i]:8} {date_str:20} {cols['ChangedFiles'][i]}")
# Out:
# Id       AuthorDate           ChangedFiles
# --------------------------------------------------------------------------------
# 606b6fd  2025-10-09 11:32
# ecf8996  2025-10-08 13:39
# 3dcdce3  2023-11-10 19:18
# 2f54b80  2023-11-10 16:31
# e56e9fa  2023-11-06 18:11
# c1ea9b9  2023-11-01 12:17
# 3c064bd  2023-10-16 16:09
# e6d2e28  2023-09-27 11:05
# 2db03bc  2023-09-27 10:53
# ac5eb35  2023-09-25 10:17
# da240a2  2023-09-18 10:42
# 43168fc  2023-09-08 11:52
# b1804b1  2023-04-30 16:20
# 691b9c8  2023-04-22 11:28
# 9fbfd46  2023-03-24 23:20
# 50c9347  2023-03-24 22:50
# 2da614b  2023-01-15 17:22
# 0d57918  2023-01-15 17:09
# fe11ad5  2023-01-14 16:10
# f503763  2022-11-24 14:42
# 4bc7ae2  2022-07-05 17:29
# ecded88  2022-06-19 10:48
# 2db0b44  2022-06-19 10:46
# fa4e2a3  2022-04-18 10:42
# bbf621e  2022-04-09 05:33
# fc31fbb  2022-02-28 10:52
# 17d103c  2021-11-03 11:51
# e44a5cc  2021-10-25 23:51
# f16d448  2021-10-25 19:10
# 5f05329  2021-09-30 12:08
# 559d785  2021-09-30 11:19
# 9df6aea  2021-05-25 15:15
# 524aac2  2021-04-20 12:27
# ab8e60d  2021-04-14 18:01
# f1e18ff  2021-04-14 17:27
# 52f7990  2021-04-13 19:03
# 8ce708c  2021-04-12 01:40
# 075f502  2021-04-11 21:05
# 4291b8c  2021-04-11 21:02
# ab9f1bc  2021-04-11 14:05
# fe2911a  2021-03-07 11:10
# a0726e5  2021-01-14 19:02
# 75363a0  2021-01-07 15:04
# f6beb60  2020-10-02 20:41
# 77cac58  2020-09-29 14:18
# b707946  2020-09-29 12:48
# 141b2dc  2020-09-29 12:19
# f259cae  2020-09-25 16:16
# eaf9c06  2020-09-25 16:57
# d330173  2020-03-09 15:12
# 133c4bf  2020-03-09 13:59
# a9435d5  2020-03-09 13:14
# a506b66  2020-03-06 21:54
# d067442  2020-03-05 19:02
# d9cbd7b  2020-03-05 11:16
# 425c46d  2020-01-23 10:10
# 6259cd0  2019-11-20 13:34
# 137182a  2019-11-19 10:30
# a9faba1  2019-08-31 23:59
# cdadb44  2019-08-07 11:33
# 300067c  2019-07-25 16:19
# 0590d1b  2019-06-14 13:46
# fabbeb7  2019-05-16 14:36
# ba18b56  2019-04-29 13:18
# 8940d58  2019-03-05 16:18
# 0910bcd  2019-03-04 11:04
# b8c7829  2019-03-04 10:41
# 91ac9bf  2019-03-01 15:28
# 31b716e  2019-03-01 09:09
# 07714c0  2019-02-28 13:00
# 435ce3b  2019-02-18 10:59
# c24fc22  2018-12-18 14:43
# 5a92521  2018-11-19 11:39
# ed222a2  2018-11-19 10:52
# abdde8f  2018-10-18 12:49
# d3a0962  2018-10-08 14:09
# 959ce75  2018-10-05 13:35
# 98c3af9  2018-09-27 16:54
# 98bf4dc  2018-09-27 13:31
# c968e6f  2018-09-14 11:38
# eef0e50  2018-09-03 17:32
# 559bae6  2018-08-29 15:52
# fb6484a  2018-08-16 15:15
# 3fc3e9a  2018-07-31 16:27
# a93b42c  2018-07-31 15:03
# 9cf252c  2018-06-25 16:21
# fc1af0c  2018-06-25 15:58
# 220bc1f  2018-06-19 15:49
# cf45e47  2018-06-19 15:44
# 7748bd5  2018-06-19 10:37
# f0d66a6  2018-06-18 10:58
# 0e47f41  2018-06-15 12:33
# 32df48a  2018-06-14 13:18
# f50d8e5  2018-06-13 15:04
# bf8da35  2018-06-13 13:32
# c30847b  2018-06-11 13:44
# ef9d708  2018-06-11 13:43
# 1bb9458  2018-06-11 09:55
# 25878a5  2018-06-08 15:51
# 0234912  2018-06-08 15:51
# e510209  2018-05-24 15:20
# 1b332c8  2018-05-15 10:11
# ffaaf75  2018-05-14 19:38
# 28a436b  2018-05-14 18:20
# 52e68c8  2018-05-08 11:22
# 09ce7af  2018-05-07 14:34
# bd9873c  2018-05-07 09:46
# f330467  2018-05-04 16:12
# 2656120  2018-05-03 14:51
# 55d56ee  2018-05-02 20:01
# d59a446  2018-05-02 17:38
# e03c861  2018-04-28 14:01
# 7914988  2018-04-27 13:02
# 0a60cdc  2018-04-25 15:17
# e4b9dc6  2018-04-03 16:16
# 670e8a0  2018-03-22 17:16
# 77398e0  2018-03-22 17:13
# f16ecac  2018-03-22 16:43
# 350f5ca  2018-03-21 17:26
# 8d6421d  2018-03-21 16:56
# ac7358f  2018-03-14 16:50
# 7c4b998  2018-03-14 16:50
# c21fd7f  2018-03-14 16:11
# eac0417  2018-03-14 15:14
# e019d4c  2018-03-14 14:49
# 05c5047  2018-03-14 14:20
# f0a36a1  2018-02-27 11:19
# 344a450  2018-01-08 15:59
# 4022e8c  2018-01-03 13:53
# f0284ac  2017-12-12 11:10
# 2354345  2017-11-29 17:11
# f884858  2017-11-28 16:57
# dfff8ff  2017-11-28 16:16
# 7240999  2017-11-28 16:16
# d5a3b66  2017-11-28 15:05
# e81d466  2017-11-27 13:00
# ce16aec  2017-11-10 15:49
# c1a95e1  2017-11-10 15:31
# 06784cd  2017-11-08 14:27
# 13d10af  2017-11-08 11:18
# 31233af  2017-11-07 20:56
# a70fc47  2017-11-07 20:55
# 85b9439  2017-11-06 17:19
# fd10644  2017-11-06 10:57
# 7bb9fae  2017-11-04 23:16
# a184e7e  2017-11-01 13:38
# b0327b0  2017-11-01 13:37
# e9ba0e4  2017-11-01 11:37
# cad565e  2017-11-01 10:21
# 4da3738  2017-10-31 13:05
# a489683  2017-10-25 14:59
# cfb7408  2017-10-25 14:58
# bc93659  2017-10-25 12:05
# 40dec01  2017-10-24 18:26
# 6c3e8bb  2017-08-18 21:07
# b384cd4  2017-08-08 10:12
# 36e6b14  2017-07-12 14:57
# edfc38a  2017-07-12 14:56
# 852fd94  2017-07-10 14:21
# 9540d0b  2017-05-26 23:06
# a7496a2  2017-05-22 13:00
# b10078b  2017-05-05 11:52
# 76df65e  2017-05-03 14:02
# 393bd56  2017-04-21 13:34
# 73f5f70  2017-04-21 13:33
# c8f5544  2017-04-18 18:04
# 1dbc671  2017-04-11 18:28
# 2424bc4  2017-04-11 13:16
# 38b1502  2017-03-31 11:04
# 5762bc3  2017-03-31 11:03
# a18f1e8  2017-03-18 13:41
# eedd971  2017-03-14 13:08
# 25909c8  2017-02-23 11:38
# 4530423  2017-02-23 10:43
# 8f000c5  2017-02-21 12:58
# 4bdc258  2017-02-20 22:14
# 83ae911  2017-02-20 22:14
# e64d9f7  2017-02-17 18:16
# 352e8a5  2017-02-16 15:28
# 9e6f400  2017-02-16 15:27
# 9c4f355  2017-02-16 13:48
# 804cea7  2017-02-16 13:43
# 9531aa9  2017-02-16 13:41
# 990fded  2017-02-07 12:59
# 46df21e  2017-02-07 12:58
# 77982f9  2017-02-07 12:57
# 4ae79a8  2017-02-07 12:57
# 6d9aaec  2017-02-01 13:27
# b9c3184  2017-01-19 19:22
# 5c92cfb  2017-01-17 15:43
# 65ced79  2017-01-09 17:16
# 84e6cf3  2017-01-09 17:15
# 823dfd6  2017-01-09 14:52
# b1454bc  2017-01-09 11:30
# 6bdacd4  2017-01-09 10:49
# 900b22e  2017-01-09 10:48
# 3df71d0  2017-01-06 12:40
# 361b2f1  2017-01-04 10:21
# 9bece08  2016-12-21 16:35
# f311624  2016-12-21 16:35
# 5560090  2016-12-21 11:47
# 941a4e1  2016-12-20 18:49
# ad6ebdc  2016-12-20 15:11
# c032666  2016-12-16 15:37
# f384cd1  2016-12-16 13:57
# c9bde54  2016-12-16 13:32
# c1a0588  2016-12-16 13:28
# 874e618  2016-12-15 15:45
# b691ab5  2016-12-13 15:57
# fafea8a  2016-12-13 10:08
# 7e63061  2016-12-12 09:46
# e7f1a48  2016-12-09 13:41
# 9a4f9f8  2016-12-09 13:40
# cd2f57a  2016-12-06 14:35
# 26704cd  2016-12-06 14:07
# 64571fb  2016-12-06 09:29
# 1ca93bf  2016-12-05 22:56
# 0f9e801  2016-12-05 19:02
# 52e7f16  2016-12-05 15:15
# b796d33  2016-12-05 14:16
# bc69972  2016-12-05 11:47
# 0aa75f8  2016-12-05 11:46
# da9b138  2016-12-05 11:15
# c8ff67e  2016-12-05 11:12
# 8247775  2016-12-03 17:41
# a8dc069  2016-12-02 14:52
# 938d0d6  2016-12-02 14:51
# cb2e3e7  2016-12-02 19:49
# a780dfa  2016-12-02 12:06
# 1d49827  2016-12-02 18:37
# 5078eee  2016-12-02 12:17
# c375fe4  2016-12-01 18:36
# 60bc309  2016-12-01 14:00
# 6ae471f  2016-12-01 09:29
# fe4b29a  2016-12-01 09:23
# 44ff95e  2016-11-30 20:51
# 43f8bcc  2016-11-30 19:10
# ff7b295  2016-11-30 17:56
# b0d57d5  2016-11-30 17:51
# 5982dcd  2016-11-30 17:27
# 2e520e7  2016-11-30 15:30
# d188aa0  2016-11-30 14:02
# 0d5a79c  2016-11-30 09:28
# 19d7375  2016-11-30 08:42
# 40979fa  2016-11-29 14:05
# aeeb049  2016-11-29 15:41
# 854f22d  2016-11-29 14:01
# 5ea5cc1  2016-11-29 10:45
# dee5c9a  2016-11-28 10:06
# ac153fc  2016-11-28 16:53
# 7b81637  2016-11-28 13:58
# 6455178  2016-11-28 13:52
# 806239e  2016-11-28 09:16
# b20f4a1  2016-11-24 13:49
# 9e4688d  2016-11-22 15:54
# 773a7ba  2016-11-22 11:22
# 8bcf827  2016-11-22 10:32
# ab3cc94  2016-11-21 09:37
# cb3f3a9  2016-11-21 09:36
# 2b56e31  2016-11-21 09:36
# 213d30e  2016-11-18 13:53
# 6140d23  2016-11-18 13:32
# 3723b53  2016-11-18 13:32
# 0aa5782  2016-11-17 08:19
# 753135a  2016-11-16 12:56
# f8767b7  2016-11-16 10:00
# 2fd4a9e  2016-11-14 16:15
# 48e2c13  2016-11-14 11:55
# c4df69b  2016-11-14 11:51
# 6a04033  2016-11-11 11:41
# 9f43c3d  2016-11-09 13:10
# e2fc76b  2016-11-09 10:49
# a5e1f72  2016-11-09 10:41
# 43eca25  2016-11-08 10:13
# c21cab3  2016-11-08 10:12
# 35b7608  2016-11-07 13:32
# db46402  2016-10-31 14:28
# 8792ab4  2016-10-31 13:16
# e93a97f  2016-10-31 13:13
# e3e5f44  2016-10-31 12:09
# 39f146f  2016-10-31 10:45
# f6884b0  2016-10-31 10:34
# f1a348e  2016-10-27 09:48
# 31e286d  2016-10-26 10:13
# acc356a  2016-10-24 13:57
# 481b2cd  2016-10-18 13:40
# 14ed831  2016-10-17 16:12
# 5a6ba9b  2016-10-17 15:59
# e4af609  2016-10-14 17:36
# 4e03e16  2016-10-14 13:26
# c9ffa9c  2016-10-14 13:16
# 4136c51  2016-10-14 13:13
# da17b37  2016-10-10 09:38
# 8501759  2016-10-10 09:36
# 48e865b  2016-10-10 09:33
# b9eca71  2016-10-07 13:15
# 89974ba  2016-10-05 10:33
# 2bed9bb  2016-10-04 08:59
# 9824304  2016-09-27 09:59
# 88acecf  2016-09-23 10:42
# fe87b7a  2016-09-23 09:54
# ce4583a  2016-09-23 09:53
# b94db84  2016-09-12 15:05
# d24fe80  2016-08-29 13:10
# 4e75c5a  2016-07-27 16:07
# 90ede10  2016-07-27 16:06
# b6b9876  2016-07-27 08:37
# 767c7c2  2016-07-26 15:47
# 84bb398  2016-07-26 10:03
# 37a15fe  2016-07-25 14:40
# b3343f9  2016-07-15 04:00
# e387105  2016-07-15 00:41
# 55adbce  2016-07-14 23:12
# 633fe82  2016-07-14 18:46
# d1952dc  2016-07-14 14:42
# 6691bfc  2016-07-14 14:14
# a8fce37  2016-07-14 10:44
# 0d9469d  2016-07-14 10:37
# 312418e  2016-07-14 01:05
# 5044f27  2016-07-13 16:32
# 015483b  2016-07-07 22:48
# b91fc89  2016-07-07 14:52
# 7fcd5b2  2016-05-11 14:24
# a3504cb  2016-05-04 17:04
# b363220  2016-05-04 11:51
# 614882b  2016-05-04 11:47
# 2e6aba7  2016-05-04 11:47
# cc31347  2016-04-21 14:34
# a0303a4  2016-04-18 10:25
# 912ee20  2016-04-17 03:38
# f173d83  2016-04-15 16:03
# d15e6fd  2016-03-22 12:00
# bc2bbfc  2016-03-21 10:11
# 6660a4a  2016-03-15 14:23
# 72fc51f  2016-03-12 21:53
# fbcb81f  2016-03-08 14:30
# 5af7f14  2016-03-08 13:56
# 24a29c2  2016-03-08 10:46
# c261edd  2016-03-08 10:42
# d20e604  2016-03-07 14:38
# 91318f6  2016-02-23 15:05
# dc6604c  2016-02-22 11:37

# %% [markdown]
# YOUR ANSWER HERE
#
# These are **merge commits** (e.g., "Merge pull request..."). Git does not list changed files in `--name-only` for merge commits.

# %% [markdown]
# ---

# %% [markdown]
# ## Đưa ra câu hỏi có ý nghĩa cần trả lời

# %% [markdown]
# Sau khi khám phá dữ liệu, ta đã hiểu hơn về dữ liệu. Bây giờ, ta hãy xem thử có câu hỏi nào có ý nghĩa mà có thể được trả lời bằng dữ liệu này không.
#
# Các câu hỏi có thể có là:
# - *Câu hỏi 1: trong năm 2021, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để khen thưởng
# - *Câu hỏi 2: commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để đổ tội cho tác giả của commit đó ;-)

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 1 (1đ)

# %% [markdown]
# Nhắc lại câu hỏi 1: *trong năm 2023, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?*
#
# Bạn sẽ lưu kết quả vào biến `wanted_people`. Biến này là một dictionary, mỗi phần tử ứng với một người mà có commit trong năm 2023, key là tên của người đó, value là số lượng commit của người đó. Dictionary này được sort theo value giảm dần.

# %%
# YOUR CODE HERE
wanted_people = {}
for i in range(num_rows):
    date = cols['AuthorDate'][i]
    if date.year == 2023:
        name = cols['AuthorName'][i]
        wanted_people[name] = wanted_people.get(name, 0) + 1

wanted_people = dict(sorted(wanted_people.items(), key=lambda x: x[1], reverse=True))

# %%
# TEST
correct_wanted_people = {'Vidar Tonaas Fauske': 62,
                         'Frédéric Collonval': 31,
                         'Florence Haudin': 18,
                         'github-actions[bot]': 14,
                         'fcollonval': 4,
                         'dependabot[bot]': 4,
                         'HaudinFlorence': 4,
                         'krassowski': 3,
                         'Michał Krassowski': 3,
                         'Chih-Hsuan Yen': 2,
                         'Angus Hollands': 1,
                         'Min RK': 1,
                         'Johan Mabille': 1,
                         'Saiwing Yeung': 1,
                         'Cory Gwin': 1}
assert wanted_people == correct_wanted_people

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 2 (2đ)

# %% [markdown]
# Nhắc lại câu hỏi 2: *commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?*
#
# Ta thống nhất: không xét các commit "merge pull request" vì các commit này không có thông tin về "ChangedFiles".
#
# Bạn lưu kết quả vào biến `wanted_commit`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một thông tin của commit, key là tên cột, value là giá trị tương ứng.

# %%
# YOUR CODE HERE
target_file = "nbdime/webapp/templates/difftool.html"
candidates = []

for i in range(num_rows):
    changed = cols['ChangedFiles'][i]
    if changed == '':
        continue
    if target_file in changed.split(','):
        parent_ids = cols['ParentIds'][i]
        subject = cols['Subject'][i]
        if ' ' in parent_ids and subject.startswith("Merge pull request"):
            continue
        candidates.append({
            'Id': cols['Id'][i],
            'ParentIds': cols['ParentIds'][i],
            'AuthorName': cols['AuthorName'][i],
            'AuthorEmail': cols['AuthorEmail'][i],
            'AuthorDate': cols['AuthorDate'][i],
            'Subject': cols['Subject'][i],
            'ChangedFiles': cols['ChangedFiles'][i]
        })

# Find the latest by AuthorDate
if candidates:
    wanted_commit = max(candidates, key=lambda x: x['AuthorDate'])
else:
    wanted_commit = {}

wanted_commit
# Out:
# {'Id': 'd39f45a',
#  'ParentIds': '8ebbc6e',
#  'AuthorName': 'Frédéric Collonval',
#  'AuthorEmail': 'fcollonval@users.noreply.github.com',
#  'AuthorDate': datetime.datetime(2023, 10, 20, 23, 20, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))),
#  'Subject': 'Do not collapse editor lines in single editor (#719)',
#  'ChangedFiles': 'nbdime/webapp/templates/compare.html,nbdime/webapp/templates/diff.html,nbdime/webapp/templates/difftool.html,nbdime/webapp/templates/merge.html,nbdime/webapp/templates/mergetool.html,packages/nbdime/src/common/mergeview.ts,ui-tests/data/merge_test6/center.ipynb,ui-tests/data/merge_test6/left.ipynb,ui-tests/data/merge_test6/right.ipynb,ui-tests/package-lock.json,ui-tests/tests/nbdime-merge-test6.spec.ts,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-linux.png,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-win32.png'}

# %%
# TEST
correct_wanted_commit = {'Id': 'd39f45a',
 'ParentIds': '8ebbc6e',
 'AuthorName': 'Frédéric Collonval',
 'AuthorEmail': 'fcollonval@users.noreply.github.com',
 'AuthorDate': datetime.datetime(2023, 10, 20, 23, 20, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))),
 'Subject': 'Do not collapse editor lines in single editor (#719)',
 'ChangedFiles': 'nbdime/webapp/templates/compare.html,nbdime/webapp/templates/diff.html,nbdime/webapp/templates/difftool.html,nbdime/webapp/templates/merge.html,nbdime/webapp/templates/mergetool.html,packages/nbdime/src/common/mergeview.ts,ui-tests/data/merge_test6/center.ipynb,ui-tests/data/merge_test6/left.ipynb,ui-tests/data/merge_test6/right.ipynb,ui-tests/package-lock.json,ui-tests/tests/nbdime-merge-test6.spec.ts,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-linux.png,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-win32.png'}
assert wanted_commit == correct_wanted_commit
